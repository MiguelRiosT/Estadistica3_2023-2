# %% [markdown]
# # Punto 2 - Final - Miguel Rios Tangarife

# %% [markdown]
# ## Crear la matriz tf-idf. Ordene las columnas por las palabras mas comunes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
encoding = 'latin1'
ruta_archivo_csv = 'data/datoss.csv'
datosFinal = pd.read_csv(ruta_archivo_csv, encoding=encoding)

# %%
# Pasamos todos los datos a minúsculas
datosFinal['Texto'] = datosFinal['Texto'].str.lower()

# %%
#Definimos stop_words
stop_words = [
    'de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se',
    'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'es',
    'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'fue', 'ha'
]

# %%
# Filtrar palabras no deseadas
datosFinal['Texto'] = datosFinal['Texto'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# Convertir todo el texto a minúsculas después de la limpieza
datosFinalClear = datosFinal.copy()
datosFinalClear['Texto'] = datosFinalClear['Texto'].str.lower()

# %%
vocabulario = set(' '.join(datosFinalClear['Texto']).split())


tf_matrix = np.zeros((len(datosFinalClear), len(vocabulario)))
for i, doc in enumerate(datosFinalClear['Texto']):
    for j, word in enumerate(vocabulario):
        tf_matrix[i, j] = doc.split().count(word)
idf_vector = np.log(len(datosFinalClear) / np.sum(tf_matrix > 0, axis=0))
tfidf_matrix = tf_matrix * idf_vector


tfidf_df = pd.DataFrame(tfidf_matrix, columns=list(vocabulario))

#Mostramos la matriz TF-IDF
tfidf_df
# Out:
#       pandas  imágenes       com    python  utilizar     texto     falto  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  2.995732  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  2.995732  0.000000  0.000000  2.995732  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  2.995732
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  2.995732  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  2.995732  0.000000  2.995732  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#       demora    tareas    confio  ...  neuronales   sabados         q  \
# 0   0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 3   0.000000  2.302585  0.000000  ...    0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 5   2.995732  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  ...    2.995732  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  ...    0.000000  2.995732  0.000000
# 13  0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 16  0.000000  2.302585  0.000000  ...    0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  ...    0.000000  0.000000  2.995732
# 18  0.000000  0.000000  0.000000  ...    0.000000  0.000000  0.000000
# 19  0.000000  0.000000  2.995732  ...    0.000000  0.000000  0.000000
#
#     grabaciones     profe   cluster     excel  entregar    utiles       me
# 0      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 1      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 2      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 3      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 4      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 5      0.000000  2.995732  0.000000  0.000000  2.995732  0.000000  0.00000
# 6      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  1.89712
# 7      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 8      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 9      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 10     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 11     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 12     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 13     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 14     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 15     0.000000  0.000000  2.995732  0.000000  0.000000  0.000000  0.00000
# 16     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 17     0.000000  0.000000  0.000000  0.000000  0.000000  2.995732  0.00000
# 18     0.000000  0.000000  0.000000  2.995732  0.000000  0.000000  1.89712
# 19     2.995732  0.000000  0.000000  0.000000  0.000000  0.000000  3.79424
#
# [20 rows x 49 columns]

# %%
plt.figure(figsize=(16, 16))
heatmap = plt.imshow(tfidf_df, cmap='inferno', aspect='equal')  
plt.colorbar(heatmap, fraction=0.03, pad=0.04)

# Agregar etiquetas de los ejes con rotación vertical
plt.xticks(np.arange(len(tfidf_df.columns)), tfidf_df.columns, rotation='vertical', ha="center")
plt.yticks(np.arange(len(tfidf_df)), tfidf_df.index)

plt.title('Matriz TF-IDF')
plt.show()

# %% [markdown]
# Realicé la misma matriz de forma diferente con el fin de interpretar mejor los datos
#
# De la matriz de TF-IDF podemos observar algunos aspectos:
# - Aprendi es una palabra que se repite mucho pero su peso no es tan alto
# - son, me, muy y tareas tienen altos valores
# - las palabras que se usaron poco tienden a tener un valor medio/alto y las palabras que se usan mucho tienden a tener menos valor
